# %%
import pandas as pd

# %%
import pandas as pd
hospice_df = pd.read_csv("data/Hospice_General_Information.csv")
hospice_df.head(2)
# Out:
#    CMS Certification Number (CCN)                          Facility Name  \
# 0                           11500                        BAPTIST HOSPICE
# 1                           11501  SOUTHERNCARE NEW BEACON N. BIRMINGHAM
#
#                  Address Line 1  Address Line 2        City State  Zip Code  \
# 0           301 INTERSTATE PARK             NaN  MONTGOMERY    AL     36109
# 1  4735 NORREL DRIVE, SUITE 129             NaN  TRUSSVILLE    AL     35173
#
#   County Name     PhoneNumber  CMS Region Ownership Type Certification Date
# 0  Montgomery  (334) 395-5000           4          Other         03/23/1984
# 1   Jefferson  (205) 939-8799           4     For-Profit         05/24/1984

# %%
hospice_df = hospice_df.loc[hospice_df.State == 'TN']
hospice_df.head(2)
# Out:
#       CMS Certification Number (CCN)               Facility Name  \
# 2889                          441501           ALIVE HOSPICE INC
# 2890                          441502  METHODIST ALLIANCE HOSPICE
#
#                          Address Line 1  Address Line 2       City State  \
# 2889                1718 PATTERSON ROAD             NaN  NASHVILLE    TN
# 2890  6400 SHELBY VIEW DRIVE, SUITE 101             NaN    MEMPHIS    TN
#
#       Zip Code County Name     PhoneNumber  CMS Region Ownership Type  \
# 2889     37203    Davidson  (615) 327-1085           4     Non-Profit
# 2890     38134      Shelby  (901) 516-1600           4     Non-Profit
#
#      Certification Date
# 2889         04/10/1984
# 2890         08/31/1984

# %%
hospice_df.columns = ['ccn', 'facility', 'address', 'address2', 'city', 'state', 'zip', 'county', 'phone', 
                      'region', 'owner_type', 'cert_data']
hospice_df.head(2)
# Out:
#          ccn                    facility                            address  \
# 2889  441501           ALIVE HOSPICE INC                1718 PATTERSON ROAD
# 2890  441502  METHODIST ALLIANCE HOSPICE  6400 SHELBY VIEW DRIVE, SUITE 101
#
#       address2       city state    zip    county           phone  region  \
# 2889       NaN  NASHVILLE    TN  37203  Davidson  (615) 327-1085       4
# 2890       NaN    MEMPHIS    TN  38134    Shelby  (901) 516-1600       4
#
#       owner_type   cert_data
# 2889  Non-Profit  04/10/1984
# 2890  Non-Profit  08/31/1984

# %% [markdown]
# hospice_df.columns = ('ccn', 'facility', 'address', 'address2', 'city', 'state', 'zip', 'county', 'phone', 'region', 'owner_type', cert_data')
# hospice_df.head(2)

# %%
hospice_df.drop(columns = ['ccn', 'address2', 'zip', 'phone'], inplace = True)

# %%
hospice_df.head()
# Out:
#                                 facility                            address  \
# 2889                   ALIVE HOSPICE INC                1718 PATTERSON ROAD
# 2890          METHODIST ALLIANCE HOSPICE  6400 SHELBY VIEW DRIVE, SUITE 101
# 2891          HOSPICE OF CHATTANOOGA INC                 4411 OAKWOOD DRIVE
# 2892               AMEDISYS HOSPICE CARE          6570 STAGE ROAD SUITE 110
# 2893  NORTHCREST HOME HEALTH AND HOSPICE               212 NORTHCREST DRIVE
#
#              city state     county  region  owner_type   cert_data
# 2889    NASHVILLE    TN   Davidson       4  Non-Profit  04/10/1984
# 2890      MEMPHIS    TN     Shelby       4  Non-Profit  08/31/1984
# 2891  CHATTANOOGA    TN   Hamilton       4  Non-Profit  06/30/1986
# 2892     BARTLETT    TN     Shelby       4  For-Profit  02/09/1987
# 2893  SPRINGFIELD    TN  Robertson       4       Other  07/13/1987

# %%
hospice_df.tail()
# Out:
#                                   facility                        address  \
# 2940        ENCOMPASS HOSPICE OF TENNESSEE    828 ROYAL PARKWAY SUITE 113
# 2941                       QUALITY HOSPICE        341 WEST CENTRAL AVENUE
# 2942                        HEARTH HOSPICE  1800A ROSSVILLE AVE SUITE 114
# 2943  AMEDISYS HOSPICE, AN ADVENTA COMPANY              400 ROYAL PARKWAY
# 2944                       KINDRED HOSPICE        430 STUART RD NE, STE 2
#
#              city state    county  region  owner_type   cert_data
# 2940    NASHVILLE    TN  Davidson       4  For-Profit  06/16/2010
# 2941    JAMESTOWN    TN  Fentress       4  For-Profit  01/04/2013
# 2942  CHATTANOOGA    TN  Hamilton       4  For-Profit  03/22/2013
# 2943    NASHVILLE    TN  Davidson       4       Other  01/05/2016
# 2944    CLEVELAND    TN   Bradley       4  For-Profit  01/04/2017

# %%
hospice_df.shape
# Out:
# (56, 8)

# %%
cancer_df = pd.read_csv("data/cancer_deaths.csv", skiprows=4, nrows = 97)
cancer_df.head()
# Out:
#              County   FIPS Met Healthy People Objective of 161.4?  \
# 0         Tennessee  47999                                     No
# 1     United States      0                                     No
# 2  Trousdale County  47169                                     No
# 3      Scott County  47151                                     No
# 4   Cheatham County  47021                                     No
#
#    Age-Adjusted Death Rate - deaths per 100,000  \
# 0                                         185.4
# 1                                         163.5
# 2                                         265.5
# 3                                         241.0
# 4                                         239.6
#
#    Lower 95% Confidence Interval  Upper 95% Confidence Interval  \
# 0                          184.0                          186.8
# 1                          163.3                          163.7
# 2                          219.0                          319.1
# 3                          214.5                          270.0
# 4                          217.8                          263.0
#
#    Average Annual Count Recent Trend  Recent 5-Year Trend in Death Rates  \
# 0                 13933      falling                                -1.4
# 1                586354      falling                                -1.5
# 2                    24       stable                                 0.0
# 3                    63       stable                                -0.5
# 4                    97       stable                                -0.6
#
#    Lower 95% Confidence Interval.1  Upper 95% Confidence Interval.1
# 0                             -1.5                             -1.2
# 1                             -1.6                             -1.5
# 2                             -1.3                              1.3
# 3                             -1.1                              0.1
# 4                             -1.4                              0.3

# %%
cancer_df.tail()
# Out:
#                County   FIPS Met Healthy People Objective of 161.4?  \
# 92   Van Buren County  47175                                    Yes
# 93     Pickett County  47137                                    Yes
# 94     Fayette County  47047                                    Yes
# 95  Williamson County  47187                                    Yes
# 96       Moore County  47127                                    Yes
#
#     Age-Adjusted Death Rate - deaths per 100,000  \
# 92                                         160.3
# 93                                         158.7
# 94                                         154.3
# 95                                         127.2
# 96                                         123.2
#
#     Lower 95% Confidence Interval  Upper 95% Confidence Interval  \
# 92                          122.7                          207.4
# 93                          123.3                          203.9
# 94                          139.1                          170.7
# 95                          119.8                          134.9
# 96                           93.9                          160.5
#
#     Average Annual Count Recent Trend  Recent 5-Year Trend in Death Rates  \
# 92                    14       stable                                -0.9
# 93                    15       stable                                -0.5
# 94                    81      falling                                -1.4
# 95                   239      falling                                -3.8
# 96                    12      falling                                -2.1
#
#     Lower 95% Confidence Interval.1  Upper 95% Confidence Interval.1
# 92                             -2.4                              0.6
# 93                             -1.8                              0.9
# 94                             -2.2                             -0.5
# 95                             -4.8                             -2.9
# 96                             -3.8                             -0.4

# %%
cancer_df.shape
# Out:
# (97, 11)

# %%
cancer_df.columns = ['county', 'FIPS', 'met_healthy_hbjective', 
                  'age_adjusted_death_rate_per_100k', 'lower_95%_CI',
                  'Upper_95%_CI', 'avg_annual_count', 'recent_trend',
                  '5year_trend_death_rates', 'lower_95%_CI_2', 'Upper_95%_CU_2']
cancer_df.head(2)
# Out:
#           county   FIPS met_healthy_hbjective  \
# 0      Tennessee  47999                    No
# 1  United States      0                    No
#
#    age_adjusted_death_rate_per_100k  lower_95%_CI  Upper_95%_CI  \
# 0                             185.4         184.0         186.8
# 1                             163.5         163.3         163.7
#
#    avg_annual_count recent_trend  5year_trend_death_rates  lower_95%_CI_2  \
# 0             13933      falling                     -1.4            -1.5
# 1            586354      falling                     -1.5            -1.6
#
#    Upper_95%_CU_2
# 0            -1.2
# 1            -1.5

# %%
pop_df = pd.read_csv('data/PEP_2017_PEPAGESEX.csv', skiprows=1)
pop_df.head(2)
# Out:
#                Id    Id2                   Geography  \
# 0  0500000US47001  47001  Anderson County, Tennessee
# 1  0500000US47003  47003   Bedford County, Tennessee
#
#    April 1, 2010 - Census - Both Sexes; Total  \
# 0                                       75129
# 1                                       45058
#
#    April 1, 2010 - Census - Male; Total  \
# 0                                 36308
# 1                                 22357
#
#    April 1, 2010 - Census - Female; Total  \
# 0                                   38821
# 1                                   22701
#
#    April 1, 2010 - Estimates Base - Both Sexes; Total  \
# 0                                              75094
# 1                                              45056
#
#    April 1, 2010 - Estimates Base - Male; Total  \
# 0                                         36288
# 1                                         22356
#
#    April 1, 2010 - Estimates Base - Female; Total  \
# 0                                           38806
# 1                                           22700
#
#    Population Estimate (as of July 1) - 2010 - Both Sexes; Total  \
# 0                                              75112
# 1                                              45086
#
#                                     ...                                    \
# 0                                   ...
# 1                                   ...
#
#    Population Estimate (as of July 1) - 2014 - Females; Median age (years)  \
# 0                                               44.8
# 1                                               38.4
#
#    Population Estimate (as of July 1) - 2015 - Both Sexes; Median age (years)  \
# 0                                               43.3
# 1                                               37.2
#
#    Population Estimate (as of July 1) - 2015 - Male; Median age (years)  \
# 0                                               41.4
# 1                                               35.9
#
#    Population Estimate (as of July 1) - 2015 - Female; Median age (years)  \
# 0                                               44.8
# 1                                               38.5
#
#    Population Estimate (as of July 1) - 2016 - Both Sexes; Median age (years)  \
# 0                                               43.3
# 1                                               37.5
#
#    Population Estimate (as of July 1) - 2016 - Male; Median age (years)  \
# 0                                               41.5
# 1                                               36.2
#
#    Population Estimate (as of July 1) - 2016 - Female; Median age (years)  \
# 0                                               45.1
# 1                                               38.8
#
#    Population Estimate (as of July 1) - 2017 - Both Sexes; Median age (years)  \
# 0                                               43.2
# 1                                               37.5
#
#    Population Estimate (as of July 1) - 2017 - Male; Median age (years)  \
# 0                                               41.2
# 1                                               36.2
#
#    Population Estimate (as of July 1) - 2017 - Female; Median age (years)
# 0                                               45.0
# 1                                               38.9
#
# [2 rows x 993 columns]

# %%
pop_df.tail()
# Out:
#                 Id    Id2                     Geography  \
# 90  0500000US47181  47181       Wayne County, Tennessee
# 91  0500000US47183  47183     Weakley County, Tennessee
# 92  0500000US47185  47185       White County, Tennessee
# 93  0500000US47187  47187  Williamson County, Tennessee
# 94  0500000US47189  47189      Wilson County, Tennessee
#
#     April 1, 2010 - Census - Both Sexes; Total  \
# 90                                       17021
# 91                                       35021
# 92                                       25841
# 93                                      183182
# 94                                      113993
#
#     April 1, 2010 - Census - Male; Total  \
# 90                                  9402
# 91                                 17159
# 92                                 12640
# 93                                 89336
# 94                                 55834
#
#     April 1, 2010 - Census - Female; Total  \
# 90                                    7619
# 91                                   17862
# 92                                   13201
# 93                                   93846
# 94                                   58159
#
#     April 1, 2010 - Estimates Base - Both Sexes; Total  \
# 90                                              17027
# 91                                              35015
# 92                                              25836
# 93                                             183252
# 94                                             114057
#
#     April 1, 2010 - Estimates Base - Male; Total  \
# 90                                          9404
# 91                                         17157
# 92                                         12637
# 93                                         89371
# 94                                         55863
#
#     April 1, 2010 - Estimates Base - Female; Total  \
# 90                                            7623
# 91                                           17858
# 92                                           13199
# 93                                           93881
# 94                                           58194
#
#     Population Estimate (as of July 1) - 2010 - Both Sexes; Total  \
# 90                                              16987
# 91                                              35042
# 92                                              25821
# 93                                             184130
# 94                                             114677
#
#                                      ...                                    \
# 90                                   ...
# 91                                   ...
# 92                                   ...
# 93                                   ...
# 94                                   ...
#
#     Population Estimate (as of July 1) - 2014 - Females; Median age (years)  \
# 90                                               45.8
# 91                                               39.2
# 92                                               44.0
# 93                                               39.7
# 94                                               41.1
#
#     Population Estimate (as of July 1) - 2015 - Both Sexes; Median age (years)  \
# 90                                               42.6
# 91                                               37.6
# 92                                               42.7
# 93                                               39.0
# 94                                               40.2
#
#     Population Estimate (as of July 1) - 2015 - Male; Median age (years)  \
# 90                                               39.8
# 91                                               36.0
# 92                                               41.0
# 93                                               38.2
# 94                                               39.2
#
#     Population Estimate (as of July 1) - 2015 - Female; Median age (years)  \
# 90                                               46.5
# 91                                               39.2
# 92                                               44.2
# 93                                               39.7
# 94                                               41.1
#
#     Population Estimate (as of July 1) - 2016 - Both Sexes; Median age (years)  \
# 90                                               42.7
# 91                                               37.9
# 92                                               42.8
# 93                                               39.0
# 94                                               40.0
#
#     Population Estimate (as of July 1) - 2016 - Male; Median age (years)  \
# 90                                               39.9
# 91                                               36.2
# 92                                               41.2
# 93                                               38.3
# 94                                               39.0
#
#     Population Estimate (as of July 1) - 2016 - Female; Median age (years)  \
# 90                                               46.7
# 91                                               39.6
# 92                                               44.3
# 93                                               39.7
# 94                                               40.9
#
#     Population Estimate (as of July 1) - 2017 - Both Sexes; Median age (years)  \
# 90                                               43.1
# 91                                               38.3
# 92                                               42.8
# 93                                               39.0
# 94                                               39.9
#
#     Population Estimate (as of July 1) - 2017 - Male; Median age (years)  \
# 90                                               40.0
# 91                                               36.6
# 92                                               41.3
# 93                                               38.3
# 94                                               39.0
#
#     Population Estimate (as of July 1) - 2017 - Female; Median age (years)
# 90                                               47.4
# 91                                               40.1
# 92                                               44.4
# 93                                               39.7
# 94                                               40.8
#
# [5 rows x 993 columns]

# %%
pop_df.shape
# Out:
# (95, 993)

# %%
pop_df.columns
# Out:
# Index(['Id', 'Id2', 'Geography', 'April 1, 2010 - Census - Both Sexes; Total',
#        'April 1, 2010 - Census - Male; Total',
#        'April 1, 2010 - Census - Female; Total',
#        'April 1, 2010 - Estimates Base - Both Sexes; Total',
#        'April 1, 2010 - Estimates Base - Male; Total',
#        'April 1, 2010 - Estimates Base - Female; Total',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total',
#        ...
#        'Population Estimate (as of July 1) - 2014 - Females; Median age (years)',
#        'Population Estimate (as of July 1) - 2015 - Both Sexes; Median age (years)',
#        'Population Estimate (as of July 1) - 2015 - Male; Median age (years)',
#        'Population Estimate (as of July 1) - 2015 - Female; Median age (years)',
#        'Population Estimate (as of July 1) - 2016 - Both Sexes; Median age (years)',
#        'Population Estimate (as of July 1) - 2016 - Male; Median age (years)',
#        'Population Estimate (as of July 1) - 2016 - Female; Median age (years)',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Median age (years)',
#        'Population Estimate (as of July 1) - 2017 - Male; Median age (years)',
#        'Population Estimate (as of July 1) - 2017 - Female; Median age (years)'],
#       dtype='object', length=993)

# %%
april_data = [col for col in pop_df.columns if col.startswith('April')]
pop_df = pop_df.drop(columns=april_data, axis = 1)

# %%
pop_df.columns
# Out:
# Index(['Id', 'Id2', 'Geography',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total',
#        'Population Estimate (as of July 1) - 2010 - Male; Total',
#        'Population Estimate (as of July 1) - 2010 - Female; Total',
#        'Population Estimate (as of July 1) - 2011 - Both Sexes; Total',
#        'Population Estimate (as of July 1) - 2011 - Male; Total',
#        'Population Estimate (as of July 1) - 2011 - Female; Total',
#        'Population Estimate (as of July 1) - 2012 - Both Sexes; Total',
#        ...
#        'Population Estimate (as of July 1) - 2014 - Females; Median age (years)',
#        'Population Estimate (as of July 1) - 2015 - Both Sexes; Median age (years)',
#        'Population Estimate (as of July 1) - 2015 - Male; Median age (years)',
#        'Population Estimate (as of July 1) - 2015 - Female; Median age (years)',
#        'Population Estimate (as of July 1) - 2016 - Both Sexes; Median age (years)',
#        'Population Estimate (as of July 1) - 2016 - Male; Median age (years)',
#        'Population Estimate (as of July 1) - 2016 - Female; Median age (years)',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Median age (years)',
#        'Population Estimate (as of July 1) - 2017 - Male; Median age (years)',
#        'Population Estimate (as of July 1) - 2017 - Female; Median age (years)'],
#       dtype='object', length=795)

# %%
pop_df.shape
# Out:
# (95, 795)

# %%
april_data = [col for col in pop_df.columns if col.startswith('April')]
pop_df = pop_df.drop(april_data, axis = 1)

# %%
pop_df.shape
# Out:
# (95, 795)

# %%
data2015 = [col for col in pop_df.columns if '2015' in col]
pop_df = pop_df.drop(data2015, axis = 1)

# %%
pop_df.shape
# Out:
# (95, 696)

# %%
data2016 = [col for col in pop_df.columns if '2016' in col]
pop_df = pop_df.drop(data2016, axis =1)

# %%
pop_df.shape
# Out:
# (95, 597)

# %%
data2011 = [col for col in pop_df.columns if '2011' in col]
pop_df = pop_df.drop(data2011, axis = 1)

# %%
pop_df.shape
# Out:
# (95, 498)

# %%
data2013 = [col for col in pop_df.columns if '2013' in col]
pop_df = pop_df.drop(data2013, axis = 1)

# %%
pop_df.shape
# Out:
# (95, 399)

# %%
male_data = [col for col in pop_df.columns if 'Male' in col]
pop_df = pop_df.drop(male_data, axis = 1)

# %%
pop_df.shape
# Out:
# (95, 267)

# %%
female_data = [col for col in pop_df.columns if 'Female' in col]
pop_df = pop_df.drop(female_data, axis = 1)

# %%
pop_df.shape
# Out:
# (95, 135)

# %%
pop_df.columns
# Out:
# Index(['Id', 'Id2', 'Geography',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total',
#        'Population Estimate (as of July 1) - 2012 - Both Sexes; Total',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - Under 5 years',
#        'Population Estimate (as of July 1) - 2012 - Both Sexes; Total - Under 5 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - Under 5 years',
#        ...
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; 18 years and over',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; 18 years and over',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; 15 to 44 years',
#        'Population Estimate (as of July 1) - 2012 - Both Sexes; 15 to 44 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; 15 to 44 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; 15 to 44 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Median age (years)',
#        'Population Estimate (as of July 1) - 2012 - Both Sexes; Median age (years)',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Median age (years)',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Median age (years)'],
#       dtype='object', length=135)

# %%
data2012 = [col for col in pop_df.columns if '2012' in col]
pop_df = pop_df.drop(data2012, axis = 1)

# %%
pop_df.shape
# Out:
# (95, 102)

# %%
pop_df.columns
# Out:
# Index(['Id', 'Id2', 'Geography',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - Under 5 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - Under 5 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - Under 5 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 5 to 9 years',
#        ...
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; 16 years and over',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; 18 years and over',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; 18 years and over',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; 18 years and over',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; 15 to 44 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; 15 to 44 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; 15 to 44 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Median age (years)',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Median age (years)',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Median age (years)'],
#       dtype='object', length=102)

# %%
data_under5 = [col for col in pop_df.columns if 'Under 5' in col]
pop_df = pop_df.drop(data_under5, axis = 1)

# %%
pop_df.shape
# Out:
# (95, 96)

# %%
data_5to9 = [col for col in pop_df.columns if '5 to 9' in col]
pop_df = pop_df.drop(data_5to9, axis = 1)

# %%
pop_df.shape
# Out:
# (95, 93)

# %%
data_15to44 = [col for col in pop_df.columns if '15 to 44' in col]
pop_df = pop_df.drop(data_15to44, axis = 1)

# %%
pop_df.shape
# Out:
# (95, 90)

# %%
pop_df.columns
# Out:
# Index(['Id', 'Id2', 'Geography',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 10 to 14 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 10 to 14 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 10 to 14 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 15 to 19 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 15 to 19 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 15 to 19 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 20 to 24 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 20 to 24 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 20 to 24 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 25 to 29 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 25 to 29 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 25 to 29 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 30 to 34 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 30 to 34 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 30 to 34 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 35 to 39 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 35 to 39 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 35 to 39 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 40 to 44 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 40 to 44 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 40 to 44 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 45 to 49 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 45 to 49 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 45 to 49 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 50 to 54 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 50 to 54 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 50 to 54 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 55 to 59 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 55 to 59 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 55 to 59 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 60 to 64 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 60 to 64 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 60 to 64 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 65 to 69 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 65 to 69 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 65 to 69 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 70 to 74 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 70 to 74 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 70 to 74 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 75 to 79 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 75 to 79 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 75 to 79 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 80 to 84 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 80 to 84 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 80 to 84 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 85 years and over',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 85 years and over',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 85 years and over',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Under 18 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Under 18 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Under 18 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Under 18 years - 5 to 13 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Under 18 years - 5 to 13 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Under 18 years - 5 to 13 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Under 18 years - 14 to 17 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Under 18 years - 14 to 17 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Under 18 years - 14 to 17 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; 18 to 64 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; 18 to 64 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; 18 to 64 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; 18 to 64 years - 18 to 24 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; 18 to 64 years - 18 to 24 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; 18 to 64 years - 18 to 24 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; 18 to 64 years - 25 to 44 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; 18 to 64 years - 25 to 44 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; 18 to 64 years - 25 to 44 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; 18 to 64 years - 45 to 64 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; 18 to 64 years - 45 to 64 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; 18 to 64 years - 45 to 64 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; 65 years and over',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; 65 years and over',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; 65 years and over',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; 85 years and over',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; 85 years and over',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; 85 years and over',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; 16 years and over',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; 16 years and over',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; 16 years and over',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; 18 years and over',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; 18 years and over',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; 18 years and over',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Median age (years)',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Median age (years)',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Median age (years)'],
#       dtype='object')

# %%
data_10to14 = [col for col in pop_df.columns if '10 to 14' in col]
pop_df = pop_df.drop(data_10to14, axis = 1)

# %%
data_15to19 = [col for col in pop_df.columns if '15 to 19' in col]
pop_df = pop_df.drop(data_15to19, axis = 1)

# %%
pop_df.shape
# Out:
# (95, 84)

# %%
data_20to24 = [col for col in pop_df.columns if '20 to 24' in col]
pop_df = pop_df.drop(data_20to24, axis = 1)

# %%
pop_df.shape
# Out:
# (95, 81)

# %%
data_25to29 = [col for col in pop_df.columns if '25 to 29' in col]
pop_df = pop_df.drop(data_25to29, axis = 1)

# %%
data_30to34 = [col for col in pop_df.columns if '30 to 34' in col]
pop_df = pop_df.drop(data_30to34, axis = 1)

# %%
data_40to44 = [col for col in pop_df.columns if '40 to 44' in col]
pop_df = pop_df.drop(data_40to44, axis = 1)

# %%
data_45to49 = [col for col in pop_df.columns if '45 to 49' in col]
pop_df = pop_df.drop(data_45to49, axis = 1)

# %%
data_under18 = [col for col in pop_df.columns if 'Under 18' in col]
pop_df = pop_df.drop(data_under18, axis = 1)

# %%
pop_df.shape
# Out:
# (95, 60)

# %%
pop_df.columns
# Out:
# Index(['Id', 'Id2', 'Geography',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 35 to 39 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 35 to 39 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 35 to 39 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 50 to 54 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 50 to 54 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 50 to 54 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 55 to 59 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 55 to 59 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 55 to 59 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 60 to 64 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 60 to 64 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 60 to 64 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 65 to 69 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 65 to 69 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 65 to 69 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 70 to 74 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 70 to 74 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 70 to 74 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 75 to 79 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 75 to 79 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 75 to 79 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 80 to 84 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 80 to 84 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 80 to 84 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 85 years and over',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 85 years and over',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 85 years and over',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; 18 to 64 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; 18 to 64 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; 18 to 64 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; 18 to 64 years - 18 to 24 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; 18 to 64 years - 18 to 24 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; 18 to 64 years - 18 to 24 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; 18 to 64 years - 25 to 44 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; 18 to 64 years - 25 to 44 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; 18 to 64 years - 25 to 44 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; 18 to 64 years - 45 to 64 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; 18 to 64 years - 45 to 64 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; 18 to 64 years - 45 to 64 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; 65 years and over',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; 65 years and over',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; 65 years and over',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; 85 years and over',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; 85 years and over',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; 85 years and over',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; 16 years and over',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; 16 years and over',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; 16 years and over',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; 18 years and over',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; 18 years and over',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; 18 years and over',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Median age (years)',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Median age (years)',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Median age (years)'],
#       dtype='object')

# %%
data_35to39 = [col for col in pop_df.columns if '35 to 39' in col]
pop_df = pop_df.drop(data_35to39, axis = 1)

# %%
pop_df.columns
# Out:
# Index(['Id', 'Id2', 'Geography',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 50 to 54 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 50 to 54 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 50 to 54 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 55 to 59 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 55 to 59 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 55 to 59 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 60 to 64 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 60 to 64 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 60 to 64 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 65 to 69 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 65 to 69 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 65 to 69 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 70 to 74 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 70 to 74 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 70 to 74 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 75 to 79 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 75 to 79 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 75 to 79 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 80 to 84 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 80 to 84 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 80 to 84 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 85 years and over',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 85 years and over',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 85 years and over',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; 18 to 64 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; 18 to 64 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; 18 to 64 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; 18 to 64 years - 18 to 24 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; 18 to 64 years - 18 to 24 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; 18 to 64 years - 18 to 24 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; 18 to 64 years - 25 to 44 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; 18 to 64 years - 25 to 44 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; 18 to 64 years - 25 to 44 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; 18 to 64 years - 45 to 64 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; 18 to 64 years - 45 to 64 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; 18 to 64 years - 45 to 64 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; 65 years and over',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; 65 years and over',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; 65 years and over',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; 85 years and over',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; 85 years and over',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; 85 years and over',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; 16 years and over',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; 16 years and over',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; 16 years and over',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; 18 years and over',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; 18 years and over',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; 18 years and over',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Median age (years)',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Median age (years)',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Median age (years)'],
#       dtype='object')

# %%
pop_df.shape
# Out:
# (95, 57)

# %%
data_18to64 = [col for col in pop_df.columns if '18 to 64 years' in col]
pop_df = pop_df.drop(data_18to64, axis = 1)

# %%
data_16over = [col for col in pop_df.columns if '16 years and over' in col]
pop_df = pop_df.drop(data_16over, axis = 1)

# %%
data_18over = [col for col in pop_df.columns if '18 years and over' in col]
pop_df = pop_df.drop(data_18over, axis = 1)

# %%
pop_df.columns
# Out:
# Index(['Id', 'Id2', 'Geography',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 50 to 54 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 50 to 54 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 50 to 54 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 55 to 59 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 55 to 59 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 55 to 59 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 60 to 64 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 60 to 64 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 60 to 64 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 65 to 69 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 65 to 69 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 65 to 69 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 70 to 74 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 70 to 74 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 70 to 74 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 75 to 79 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 75 to 79 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 75 to 79 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 80 to 84 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 80 to 84 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 80 to 84 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 85 years and over',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 85 years and over',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 85 years and over',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; 65 years and over',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; 65 years and over',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; 65 years and over',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; 85 years and over',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; 85 years and over',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; 85 years and over',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Median age (years)',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Median age (years)',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Median age (years)'],
#       dtype='object')

# %%
pop_df.head(2)
# Out:
#                Id    Id2                   Geography  \
# 0  0500000US47001  47001  Anderson County, Tennessee
# 1  0500000US47003  47003   Bedford County, Tennessee
#
#    Population Estimate (as of July 1) - 2010 - Both Sexes; Total  \
# 0                                              75112
# 1                                              45086
#
#    Population Estimate (as of July 1) - 2014 - Both Sexes; Total  \
# 0                                              75131
# 1                                              46259
#
#    Population Estimate (as of July 1) - 2017 - Both Sexes; Total  \
# 0                                              76257
# 1                                              48117
#
#    Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 50 to 54 years  \
# 0                                               5850
# 1                                               3043
#
#    Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 50 to 54 years  \
# 0                                               5690
# 1                                               3207
#
#    Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 50 to 54 years  \
# 0                                               5296
# 1                                               3239
#
#    Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 55 to 59 years  \
# 0                                               5577
# 1                                               2646
#
#                                       ...                                      \
# 0                                     ...
# 1                                     ...
#
#    Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 85 years and over  \
# 0                                               2173
# 1                                                640
#
#    Population Estimate (as of July 1) - 2010 - Both Sexes; 65 years and over  \
# 0                                              13075
# 1                                               5864
#
#    Population Estimate (as of July 1) - 2014 - Both Sexes; 65 years and over  \
# 0                                              14099
# 1                                               6651
#
#    Population Estimate (as of July 1) - 2017 - Both Sexes; 65 years and over  \
# 0                                              15095
# 1                                               7261
#
#    Population Estimate (as of July 1) - 2010 - Both Sexes; 85 years and over  \
# 0                                               2135
# 1                                                647
#
#    Population Estimate (as of July 1) - 2014 - Both Sexes; 85 years and over  \
# 0                                               2211
# 1                                                679
#
#    Population Estimate (as of July 1) - 2017 - Both Sexes; 85 years and over  \
# 0                                               2173
# 1                                                640
#
#    Population Estimate (as of July 1) - 2010 - Both Sexes; Median age (years)  \
# 0                                               42.6
# 1                                               36.5
#
#    Population Estimate (as of July 1) - 2014 - Both Sexes; Median age (years)  \
# 0                                               43.3
# 1                                               37.2
#
#    Population Estimate (as of July 1) - 2017 - Both Sexes; Median age (years)
# 0                                               43.2
# 1                                               37.5
#
# [2 rows x 39 columns]

# %%
data_id = [col for col in pop_df.columns if 'Id' in col]
pop_df = pop_df.drop(data_id, axis = 1)

# %%
pop_df.head(2)
# Out:
#                     Geography  \
# 0  Anderson County, Tennessee
# 1   Bedford County, Tennessee
#
#    Population Estimate (as of July 1) - 2010 - Both Sexes; Total  \
# 0                                              75112
# 1                                              45086
#
#    Population Estimate (as of July 1) - 2014 - Both Sexes; Total  \
# 0                                              75131
# 1                                              46259
#
#    Population Estimate (as of July 1) - 2017 - Both Sexes; Total  \
# 0                                              76257
# 1                                              48117
#
#    Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 50 to 54 years  \
# 0                                               5850
# 1                                               3043
#
#    Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 50 to 54 years  \
# 0                                               5690
# 1                                               3207
#
#    Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 50 to 54 years  \
# 0                                               5296
# 1                                               3239
#
#    Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 55 to 59 years  \
# 0                                               5577
# 1                                               2646
#
#    Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 55 to 59 years  \
# 0                                               5689
# 1                                               2938
#
#    Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 55 to 59 years  \
# 0                                               5643
# 1                                               3143
#
#                                       ...                                      \
# 0                                     ...
# 1                                     ...
#
#    Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 85 years and over  \
# 0                                               2173
# 1                                                640
#
#    Population Estimate (as of July 1) - 2010 - Both Sexes; 65 years and over  \
# 0                                              13075
# 1                                               5864
#
#    Population Estimate (as of July 1) - 2014 - Both Sexes; 65 years and over  \
# 0                                              14099
# 1                                               6651
#
#    Population Estimate (as of July 1) - 2017 - Both Sexes; 65 years and over  \
# 0                                              15095
# 1                                               7261
#
#    Population Estimate (as of July 1) - 2010 - Both Sexes; 85 years and over  \
# 0                                               2135
# 1                                                647
#
#    Population Estimate (as of July 1) - 2014 - Both Sexes; 85 years and over  \
# 0                                               2211
# 1                                                679
#
#    Population Estimate (as of July 1) - 2017 - Both Sexes; 85 years and over  \
# 0                                               2173
# 1                                                640
#
#    Population Estimate (as of July 1) - 2010 - Both Sexes; Median age (years)  \
# 0                                               42.6
# 1                                               36.5
#
#    Population Estimate (as of July 1) - 2014 - Both Sexes; Median age (years)  \
# 0                                               43.3
# 1                                               37.2
#
#    Population Estimate (as of July 1) - 2017 - Both Sexes; Median age (years)
# 0                                               43.2
# 1                                               37.5
#
# [2 rows x 37 columns]

# %%
pop_df.columns
# Out:
# Index(['Geography',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 50 to 54 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 50 to 54 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 50 to 54 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 55 to 59 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 55 to 59 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 55 to 59 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 60 to 64 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 60 to 64 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 60 to 64 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 65 to 69 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 65 to 69 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 65 to 69 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 70 to 74 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 70 to 74 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 70 to 74 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 75 to 79 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 75 to 79 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 75 to 79 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 80 to 84 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 80 to 84 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 80 to 84 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 85 years and over',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 85 years and over',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 85 years and over',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; 65 years and over',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; 65 years and over',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; 65 years and over',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; 85 years and over',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; 85 years and over',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; 85 years and over',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Median age (years)',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Median age (years)',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Median age (years)'],
#       dtype='object')

# %%
data_65over = [col for col in pop_df.columns if '65 years and over' in col]
pop_df = pop_df.drop(data_65over, axis = 1)

# %%
pop_df.columns
# Out:
# Index(['Geography',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 50 to 54 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 50 to 54 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 50 to 54 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 55 to 59 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 55 to 59 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 55 to 59 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 60 to 64 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 60 to 64 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 60 to 64 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 65 to 69 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 65 to 69 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 65 to 69 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 70 to 74 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 70 to 74 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 70 to 74 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 75 to 79 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 75 to 79 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 75 to 79 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 80 to 84 years',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 80 to 84 years',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 80 to 84 years',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Total - 85 years and over',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Total - 85 years and over',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Total - 85 years and over',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; 85 years and over',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; 85 years and over',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; 85 years and over',
#        'Population Estimate (as of July 1) - 2010 - Both Sexes; Median age (years)',
#        'Population Estimate (as of July 1) - 2014 - Both Sexes; Median age (years)',
#        'Population Estimate (as of July 1) - 2017 - Both Sexes; Median age (years)'],
#       dtype='object')

# %%
pop_df.shape
# Out:
# (95, 34)

# %%
data_85over = [col for col in pop_df.columns if 'Both Sexes; 85 years' in col]
pop_df = pop_df.drop(data_85over, axis = 1)

# %%
pop_df.shape
# Out:
# (95, 31)

# %%
pop_df.columns = ['county', 'pop2010all', 'pop2014all', 'pop2017all', 'pop2010_50to54','pop2014_50to54', 'pop2017_50to54', 'pop2010_55to59', 'pop2014_55to59', 'pop2017_55to59', 'pop2010_60to64', 'pop2014_60to64', 'pop2017_60to64', 'pop2010_65to69', 'pop2014_65to69', 'pop2017_65to69', 'pop2010_70to74', 'pop2014_70to74', 'pop2017_70to74', 'pop2010_75to79', 'pop2014_75to79', 'pop2017_75to79', 'pop2010_80to84', 'pop2014_80to84', 'pop2017_80to84', 'pop2010_85over', 'pop2014_85over', 'pop2017_85over', 'median_age_2010', 'median_age_2014', 'median_age_2017']
pop_df.head(2)
# Out:
#                        county  pop2010all  pop2014all  pop2017all  \
# 0  Anderson County, Tennessee       75112       75131       76257
# 1   Bedford County, Tennessee       45086       46259       48117
#
#    pop2010_50to54  pop2014_50to54  pop2017_50to54  pop2010_55to59  \
# 0            5850            5690            5296            5577
# 1            3043            3207            3239            2646
#
#    pop2014_55to59  pop2017_55to59       ...         pop2017_75to79  \
# 0            5689            5643       ...                   2501
# 1            2938            3143       ...                   1321
#
#    pop2010_80to84  pop2014_80to84  pop2017_80to84  pop2010_85over  \
# 0            1969            1779            1785            2135
# 1             756             729             811             647
#
#    pop2014_85over  pop2017_85over  median_age_2010  median_age_2014  \
# 0            2211            2173             42.6             43.3
# 1             679             640             36.5             37.2
#
#    median_age_2017
# 0             43.2
# 1             37.5
#
# [2 rows x 31 columns]

# %%
# remove state name from pop_df.county
pop_df.county = pop_df.county.str.replace(', Tennessee', '')
pop_df.head(2)
# Out:
#             county  pop2010all  pop2014all  pop2017all  pop2010_50to54  \
# 0  Anderson County       75112       75131       76257            5850
# 1   Bedford County       45086       46259       48117            3043
#
#    pop2014_50to54  pop2017_50to54  pop2010_55to59  pop2014_55to59  \
# 0            5690            5296            5577            5689
# 1            3207            3239            2646            2938
#
#    pop2017_55to59       ...         pop2017_75to79  pop2010_80to84  \
# 0            5643       ...                   2501            1969
# 1            3143       ...                   1321             756
#
#    pop2014_80to84  pop2017_80to84  pop2010_85over  pop2014_85over  \
# 0            1779            1785            2135            2211
# 1             729             811             647             679
#
#    pop2017_85over  median_age_2010  median_age_2014  median_age_2017
# 0            2173             42.6             43.3             43.2
# 1             640             36.5             37.2             37.5
#
# [2 rows x 31 columns]

# %%
pop_and_cancer = pd.merge(pop_df, cancer_df, on = 'county', how = 'outer')
pop_and_cancer.head(2)
# Out:
#             county  pop2010all  pop2014all  pop2017all  pop2010_50to54  \
# 0  Anderson County     75112.0     75131.0     76257.0          5850.0
# 1   Bedford County     45086.0     46259.0     48117.0          3043.0
#
#    pop2014_50to54  pop2017_50to54  pop2010_55to59  pop2014_55to59  \
# 0          5690.0          5296.0          5577.0          5689.0
# 1          3207.0          3239.0          2646.0          2938.0
#
#    pop2017_55to59       ...         FIPS  met_healthy_hbjective  \
# 0          5643.0       ...        47001                     No
# 1          3143.0       ...        47003                     No
#
#    age_adjusted_death_rate_per_100k  lower_95%_CI  Upper_95%_CI  \
# 0                             180.6         169.1         192.7
# 1                             182.7         166.1         200.6
#
#    avg_annual_count  recent_trend  5year_trend_death_rates  lower_95%_CI_2  \
# 0               195       falling                     -0.7            -1.2
# 1                92       falling                     -0.7            -1.4
#
#    Upper_95%_CU_2
# 0            -0.2
# 1            -0.1
#
# [2 rows x 41 columns]

# %%
pop_and_cancer.county = pop_and_cancer.county.str.replace(' County', '')

# %%
hospice_per_county = hospice_df.county.value_counts().to_dict()

# %%
hospice_per_county
# Out:
# {'Davidson': 8,
#  'Shelby': 5,
#  'Hamilton': 5,
#  'Knox': 5,
#  'Washington': 2,
#  'Madison': 2,
#  'Carroll': 2,
#  'Bradley': 2,
#  'Williamson': 2,
#  'Robertson': 2,
#  'Sumner': 1,
#  'Wayne': 1,
#  'Putnam': 1,
#  'Blount': 1,
#  'McMinn': 1,
#  'Cumberland': 1,
#  'Fayette': 1,
#  'Henry': 1,
#  'Cocke': 1,
#  'Montgomery': 1,
#  'Lincoln': 1,
#  'Obion': 1,
#  'Coffee': 1,
#  'Perry': 1,
#  'Hancock': 1,
#  'Carter': 1,
#  'Rutherford': 1,
#  'Claiborne': 1,
#  'Sullivan': 1,
#  'Fentress': 1,
#  'Hamblen': 1}

# %%
for county in pop_and_cancer.county:
    if county in hospice_per_county:
        continue
    else:
        hospice_per_county[county] = 0

# %%
hospice_per_county
# Out:
# {'Davidson': 8,
#  'Shelby': 5,
#  'Hamilton': 5,
#  'Knox': 5,
#  'Washington': 2,
#  'Madison': 2,
#  'Carroll': 2,
#  'Bradley': 2,
#  'Williamson': 2,
#  'Robertson': 2,
#  'Sumner': 1,
#  'Wayne': 1,
#  'Putnam': 1,
#  'Blount': 1,
#  'McMinn': 1,
#  'Cumberland': 1,
#  'Fayette': 1,
#  'Henry': 1,
#  'Cocke': 1,
#  'Montgomery': 1,
#  'Lincoln': 1,
#  'Obion': 1,
#  'Coffee': 1,
#  'Perry': 1,
#  'Hancock': 1,
#  'Carter': 1,
#  'Rutherford': 1,
#  'Claiborne': 1,
#  'Sullivan': 1,
#  'Fentress': 1,
#  'Hamblen': 1,
#  'Anderson': 0,
#  'Bedford': 0,
#  'Benton': 0,
#  'Bledsoe': 0,
#  'Campbell': 0,
#  'Cannon': 0,
#  'Cheatham': 0,
#  'Chester': 0,
#  'Clay': 0,
#  'Crockett': 0,
#  'Decatur': 0,
#  'DeKalb': 0,
#  'Dickson': 0,
#  'Dyer': 0,
#  'Franklin': 0,
#  'Gibson': 0,
#  'Giles': 0,
#  'Grainger': 0,
#  'Greene': 0,
#  'Grundy': 0,
#  'Hardeman': 0,
#  'Hardin': 0,
#  'Hawkins': 0,
#  'Haywood': 0,
#  'Henderson': 0,
#  'Hickman': 0,
#  'Houston': 0,
#  'Humphreys': 0,
#  'Jackson': 0,
#  'Jefferson': 0,
#  'Johnson': 0,
#  'Lake': 0,
#  'Lauderdale': 0,
#  'Lawrence': 0,
#  'Lewis': 0,
#  'Loudon': 0,
#  'McNairy': 0,
#  'Macon': 0,
#  'Marion': 0,
#  'Marshall': 0,
#  'Maury': 0,
#  'Meigs': 0,
#  'Monroe': 0,
#  'Moore': 0,
#  'Morgan': 0,
#  'Overton': 0,
#  'Pickett': 0,
#  'Polk': 0,
#  'Rhea': 0,
#  'Roane': 0,
#  'Scott': 0,
#  'Sequatchie': 0,
#  'Sevier': 0,
#  'Smith': 0,
#  'Stewart': 0,
#  'Tipton': 0,
#  'Trousdale': 0,
#  'Unicoi': 0,
#  'Union': 0,
#  'Van Buren': 0,
#  'Warren': 0,
#  'Weakley': 0,
#  'White': 0,
#  'Wilson': 0,
#  'Tennessee': 0,
#  'United States': 0}

# %%
pop_and_cancer['hospice_count'] = [hospice_per_county[county] for county in pop_and_cancer.county]
pop_and_cancer.head()
# Out:
#      county  pop2010all  pop2014all  pop2017all  pop2010_50to54  \
# 0  Anderson     75112.0     75131.0     76257.0          5850.0
# 1   Bedford     45086.0     46259.0     48117.0          3043.0
# 2    Benton     16511.0     16176.0     15986.0          1259.0
# 3   Bledsoe     12882.0     14419.0     14717.0          1005.0
# 4    Blount    123213.0    125827.0    129929.0          9152.0
#
#    pop2014_50to54  pop2017_50to54  pop2010_55to59  pop2014_55to59  \
# 0          5690.0          5296.0          5577.0          5689.0
# 1          3207.0          3239.0          2646.0          2938.0
# 2          1204.0          1179.0          1224.0          1239.0
# 3          1216.0          1185.0           903.0          1100.0
# 4          9658.0          9522.0          8657.0          9094.0
#
#    pop2017_55to59      ...        met_healthy_hbjective  \
# 0          5643.0      ...                           No
# 1          3143.0      ...                           No
# 2          1206.0      ...                           No
# 3          1197.0      ...                           No
# 4          9615.0      ...                           No
#
#    age_adjusted_death_rate_per_100k  lower_95%_CI  Upper_95%_CI  \
# 0                             180.6         169.1         192.7
# 1                             182.7         166.1         200.6
# 2                             233.9         207.1         263.6
# 3                             170.0         143.5         200.6
# 4                             168.2         159.4         177.4
#
#    avg_annual_count  recent_trend  5year_trend_death_rates  lower_95%_CI_2  \
# 0               195       falling                     -0.7            -1.2
# 1                92       falling                     -0.7            -1.4
# 2                59        stable                      0.3            -0.4
# 3                31       falling                     -1.3            -2.3
# 4               283       falling                     -0.9            -1.3
#
#    Upper_95%_CU_2  hospice_count
# 0            -0.2              0
# 1            -0.1              0
# 2             1.1              0
# 3            -0.3              0
# 4            -0.4              1
#
# [5 rows x 42 columns]

# %%
pop_and_cancer.isnull().sum()
# Out:
# county                              0
# pop2010all                          2
# pop2014all                          2
# pop2017all                          2
# pop2010_50to54                      2
# pop2014_50to54                      2
# pop2017_50to54                      2
# pop2010_55to59                      2
# pop2014_55to59                      2
# pop2017_55to59                      2
# pop2010_60to64                      2
# pop2014_60to64                      2
# pop2017_60to64                      2
# pop2010_65to69                      2
# pop2014_65to69                      2
# pop2017_65to69                      2
# pop2010_70to74                      2
# pop2014_70to74                      2
# pop2017_70to74                      2
# pop2010_75to79                      2
# pop2014_75to79                      2
# pop2017_75to79                      2
# pop2010_80to84                      2
# pop2014_80to84                      2
# pop2017_80to84                      2
# pop2010_85over                      2
# pop2014_85over                      2
# pop2017_85over                      2
# median_age_2010                     2
# median_age_2014                     2
# median_age_2017                     2
# FIPS                                0
# met_healthy_hbjective               0
# age_adjusted_death_rate_per_100k    0
# lower_95%_CI                        0
# Upper_95%_CI                        0
# avg_annual_count                    0
# recent_trend                        0
# 5year_trend_death_rates             0
# lower_95%_CI_2                      0
# Upper_95%_CU_2                      0
# hospice_count                       0
# dtype: int64

# %%
pop_and_cancer.loc[pop_and_cancer.median_age_2017.isnull()]
# Out:
#            county  pop2010all  pop2014all  pop2017all  pop2010_50to54  \
# 95      Tennessee         NaN         NaN         NaN             NaN
# 96  United States         NaN         NaN         NaN             NaN
#
#     pop2014_50to54  pop2017_50to54  pop2010_55to59  pop2014_55to59  \
# 95             NaN             NaN             NaN             NaN
# 96             NaN             NaN             NaN             NaN
#
#     pop2017_55to59      ...        met_healthy_hbjective  \
# 95             NaN      ...                           No
# 96             NaN      ...                           No
#
#     age_adjusted_death_rate_per_100k  lower_95%_CI  Upper_95%_CI  \
# 95                             185.4         184.0         186.8
# 96                             163.5         163.3         163.7
#
#     avg_annual_count  recent_trend  5year_trend_death_rates  lower_95%_CI_2  \
# 95             13933       falling                     -1.4            -1.5
# 96            586354       falling                     -1.5            -1.6
#
#     Upper_95%_CU_2  hospice_count
# 95            -1.2              0
# 96            -1.5              0
#
# [2 rows x 42 columns]

# %%
pop_and_cancer.drop(pop_and_cancer.index[95:97], inplace = True)

# %%
pop_and_cancer.head()
# Out:
#      county  pop2010all  pop2014all  pop2017all  pop2010_50to54  \
# 0  Anderson     75112.0     75131.0     76257.0          5850.0
# 1   Bedford     45086.0     46259.0     48117.0          3043.0
# 2    Benton     16511.0     16176.0     15986.0          1259.0
# 3   Bledsoe     12882.0     14419.0     14717.0          1005.0
# 4    Blount    123213.0    125827.0    129929.0          9152.0
#
#    pop2014_50to54  pop2017_50to54  pop2010_55to59  pop2014_55to59  \
# 0          5690.0          5296.0          5577.0          5689.0
# 1          3207.0          3239.0          2646.0          2938.0
# 2          1204.0          1179.0          1224.0          1239.0
# 3          1216.0          1185.0           903.0          1100.0
# 4          9658.0          9522.0          8657.0          9094.0
#
#    pop2017_55to59      ...        met_healthy_hbjective  \
# 0          5643.0      ...                           No
# 1          3143.0      ...                           No
# 2          1206.0      ...                           No
# 3          1197.0      ...                           No
# 4          9615.0      ...                           No
#
#    age_adjusted_death_rate_per_100k  lower_95%_CI  Upper_95%_CI  \
# 0                             180.6         169.1         192.7
# 1                             182.7         166.1         200.6
# 2                             233.9         207.1         263.6
# 3                             170.0         143.5         200.6
# 4                             168.2         159.4         177.4
#
#    avg_annual_count  recent_trend  5year_trend_death_rates  lower_95%_CI_2  \
# 0               195       falling                     -0.7            -1.2
# 1                92       falling                     -0.7            -1.4
# 2                59        stable                      0.3            -0.4
# 3                31       falling                     -1.3            -2.3
# 4               283       falling                     -0.9            -1.3
#
#    Upper_95%_CU_2  hospice_count
# 0            -0.2              0
# 1            -0.1              0
# 2             1.1              0
# 3            -0.3              0
# 4            -0.4              1
#
# [5 rows x 42 columns]

# %%
pop_and_cancer.describe()
# Out:
#           pop2010all     pop2014all     pop2017all  pop2010_50to54  \
# count      95.000000      95.000000      95.000000       95.000000
# mean    66904.021053   68842.178947   70694.568421     4841.315789
# std    125893.866158  130411.224371  133087.373795     8882.143047
# min      5073.000000    5068.000000    5073.000000      364.000000
# 25%     18102.000000   17871.500000   17632.000000     1318.500000
# 50%     31821.000000   31250.000000   31609.000000     2282.000000
# 75%     56534.500000   56319.000000   56473.500000     4279.500000
# max    928552.000000  938434.000000  936961.000000    66350.000000
#
#        pop2014_50to54  pop2017_50to54  pop2010_55to59  pop2014_55to59  \
# count       95.000000       95.000000       95.000000       95.000000
# mean      4893.094737     4725.642105     4394.715789     4695.926316
# std       8879.997900     8364.067423     7931.421146     8499.962005
# min        387.000000      376.000000      385.000000      364.000000
# 25%       1289.500000     1267.000000     1273.000000     1294.000000
# 50%       2210.000000     2178.000000     2183.000000     2209.000000
# 75%       4141.500000     4093.000000     3836.500000     4105.500000
# max      64536.000000    59532.000000    59228.000000    62411.000000
#
#        pop2017_55to59  pop2010_60to64      ...        median_age_2017  \
# count       95.000000       95.000000      ...              95.000000
# mean      4786.389474     3936.094737      ...              42.227368
# std       8472.943999     6478.377453      ...               3.565450
# min        394.000000      433.000000      ...              30.800000
# 25%       1270.500000     1233.500000      ...              39.700000
# 50%       2218.000000     2080.000000      ...              42.800000
# 75%       4258.500000     4012.500000      ...              44.700000
# max      60997.000000    47519.000000      ...              51.400000
#
#                FIPS  age_adjusted_death_rate_per_100k  lower_95%_CI  \
# count     95.000000                         95.000000     95.000000
# mean   47095.000000                        195.872632    175.560000
# std       55.136195                         23.583566     20.600555
# min    47001.000000                        123.200000     93.900000
# 25%    47048.000000                        181.050000    166.450000
# 50%    47095.000000                        194.900000    176.000000
# 75%    47142.000000                        211.300000    186.950000
# max    47189.000000                        265.500000    219.000000
#
#        Upper_95%_CI  avg_annual_count  5year_trend_death_rates  \
# count     95.000000         95.000000                95.000000
# mean     218.483158        146.694737                -0.696842
# std       30.131311        236.906035                 0.996852
# min      134.900000         12.000000                -6.700000
# 25%      199.250000         47.500000                -0.950000
# 50%      215.500000         82.000000                -0.600000
# 75%      239.400000        144.500000                -0.200000
# max      319.100000       1767.000000                 1.300000
#
#        lower_95%_CI_2  Upper_95%_CU_2  hospice_count
# count       95.000000       95.000000      95.000000
# mean        -1.534737        0.162105       0.589474
# std          1.600450        0.786884       1.267387
# min        -13.800000       -2.900000       0.000000
# 25%         -1.550000       -0.300000       0.000000
# 50%         -1.200000        0.200000       0.000000
# 75%         -1.000000        0.550000       1.000000
# max          0.300000        2.300000       8.000000
#
# [8 rows x 39 columns]

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
plt.hist(pop_and_cancer['5year_trend_death_rates'])
# Out:
# (array([ 1.,  0.,  0.,  2.,  1.,  3.,  7., 54., 24.,  3.]),
#  array([-6.7, -5.9, -5.1, -4.3, -3.5, -2.7, -1.9, -1.1, -0.3,  0.5,  1.3]),
#  <a list of 10 Patch objects>)

# %%
plt.figure(figsize = (15,8))
plt.bar(pop_and_cancer['county'], pop_and_cancer['met_healthy_hbjective'], )
plt.xticks(rotation = 90)
plt.show()

# %%
plt.scatter(pop_and_cancer['county'], pop_and_cancer['hospice_count'])

# %%
plt.figure(figsize = (15,8))
plt.scatter(pop_and_cancer['county'], pop_and_cancer['age_adjusted_death_rate_per_100k'])
plt.xticks(rotation = 90)
plt.show();

# %%
pop_and_cancer.nlargest(5, 'age_adjusted_death_rate_per_100k')
# Out:
#        county  pop2010all  pop2014all  pop2017all  pop2010_50to54  \
# 84  Trousdale      7874.0      7993.0     10083.0           605.0
# 75      Scott     22227.0     21986.0     21989.0          1521.0
# 10   Cheatham     39122.0     39604.0     40330.0          3249.0
# 12  Claiborne     32216.0     31529.0     31609.0          2374.0
# 33    Hancock      6802.0      6624.0      6600.0           549.0
#
#     pop2014_50to54  pop2017_50to54  pop2010_55to59  pop2014_55to59  \
# 84           599.0           639.0           562.0           597.0
# 75          1530.0          1558.0          1446.0          1464.0
# 10          3397.0          3280.0          2723.0          2974.0
# 12          2180.0          2262.0          2361.0          2359.0
# 33           480.0           451.0           522.0           529.0
#
#     pop2017_55to59      ...        met_healthy_hbjective  \
# 84           616.0      ...                           No
# 75          1426.0      ...                           No
# 10          3224.0      ...                           No
# 12          2218.0      ...                           No
# 33           513.0      ...                           No
#
#     age_adjusted_death_rate_per_100k  lower_95%_CI  Upper_95%_CI  \
# 84                             265.5         219.0         319.1
# 75                             241.0         214.5         270.0
# 10                             239.6         217.8         263.0
# 12                             237.3         216.4         259.8
# 33                             236.2         193.1         287.1
#
#     avg_annual_count  recent_trend  5year_trend_death_rates  lower_95%_CI_2  \
# 84                24        stable                      0.0            -1.3
# 75                63        stable                     -0.5            -1.1
# 10                97        stable                     -0.6            -1.4
# 12               100        stable                     -0.1            -0.7
# 33                22        stable                      0.4            -0.8
#
#     Upper_95%_CU_2  hospice_count
# 84             1.3              0
# 75             0.1              0
# 10             0.3              0
# 12             0.4              1
# 33             1.6              1
#
# [5 rows x 42 columns]

# %%
pop_and_cancer[pop_and_cancer.hospice_count > 2]
# Out:
#       county  pop2010all  pop2014all  pop2017all  pop2010_50to54  \
# 18  Davidson    627973.0    670314.0    691243.0         42340.0
# 32  Hamilton    337262.0    350602.0    361613.0         25237.0
# 46      Knox    432972.0    447939.0    461860.0         30819.0
# 78    Shelby    928552.0    938434.0    936961.0         66350.0
#
#     pop2014_50to54  pop2017_50to54  pop2010_55to59  pop2014_55to59  \
# 18         43565.0         40889.0         37772.0         41623.0
# 32         24725.0         23736.0         23644.0         24948.0
# 46         31248.0         29955.0         28163.0         29577.0
# 78         64536.0         59532.0         59228.0         62411.0
#
#     pop2017_55to59      ...        met_healthy_hbjective  \
# 18         41751.0      ...                           No
# 32         24791.0      ...                           No
# 46         29921.0      ...                           No
# 78         60997.0      ...                           No
#
#     age_adjusted_death_rate_per_100k  lower_95%_CI  Upper_95%_CI  \
# 18                             184.7         179.8         189.7
# 32                             172.6         167.0         178.3
# 46                             177.4         172.1         182.8
# 78                             195.0         190.8         199.2
#
#     avg_annual_count  recent_trend  5year_trend_death_rates  lower_95%_CI_2  \
# 18              1137       falling                     -1.5            -1.7
# 32               743        stable                      0.1            -1.5
# 46               890       falling                     -1.0            -1.2
# 78              1767       falling                     -1.1            -1.2
#
#     Upper_95%_CU_2  hospice_count
# 18            -1.2              8
# 32             1.8              5
# 46            -0.8              5
# 78            -1.0              5
#
# [4 rows x 42 columns]

# %%
pop_and_cancer.head()
# Out:
#      county  pop2010all  pop2014all  pop2017all  pop2010_50to54  \
# 0  Anderson     75112.0     75131.0     76257.0          5850.0
# 1   Bedford     45086.0     46259.0     48117.0          3043.0
# 2    Benton     16511.0     16176.0     15986.0          1259.0
# 3   Bledsoe     12882.0     14419.0     14717.0          1005.0
# 4    Blount    123213.0    125827.0    129929.0          9152.0
#
#    pop2014_50to54  pop2017_50to54  pop2010_55to59  pop2014_55to59  \
# 0          5690.0          5296.0          5577.0          5689.0
# 1          3207.0          3239.0          2646.0          2938.0
# 2          1204.0          1179.0          1224.0          1239.0
# 3          1216.0          1185.0           903.0          1100.0
# 4          9658.0          9522.0          8657.0          9094.0
#
#    pop2017_55to59      ...        met_healthy_hbjective  \
# 0          5643.0      ...                           No
# 1          3143.0      ...                           No
# 2          1206.0      ...                           No
# 3          1197.0      ...                           No
# 4          9615.0      ...                           No
#
#    age_adjusted_death_rate_per_100k  lower_95%_CI  Upper_95%_CI  \
# 0                             180.6         169.1         192.7
# 1                             182.7         166.1         200.6
# 2                             233.9         207.1         263.6
# 3                             170.0         143.5         200.6
# 4                             168.2         159.4         177.4
#
#    avg_annual_count  recent_trend  5year_trend_death_rates  lower_95%_CI_2  \
# 0               195       falling                     -0.7            -1.2
# 1                92       falling                     -0.7            -1.4
# 2                59        stable                      0.3            -0.4
# 3                31       falling                     -1.3            -2.3
# 4               283       falling                     -0.9            -1.3
#
#    Upper_95%_CU_2  hospice_count
# 0            -0.2              0
# 1            -0.1              0
# 2             1.1              0
# 3            -0.3              0
# 4            -0.4              1
#
# [5 rows x 42 columns]

# %% [markdown]
# ### Did this run?

# %%
pop_and_cancer['over_50_2010'] = pop_and_cancer['pop2010_50to54'] + pop_and_cancer['pop2010_55to59'] + pop_and_cancer['pop2010_60to64'] + pop_and_cancer['pop2010_65to69'] + pop_and_cancer['pop2010_70to74'] + pop_and_cancer['pop2010_75to79'] + pop_and_cancer['pop2010_80to84'] + pop_and_cancer['pop2010_85over']
#pop_and_cancer['over_50_2010']

# %%
pop_and_cancer['over_50_2014'] = pop_and_cancer['pop2014_50to54'] + pop_and_cancer['pop2014_55to59']+ pop_and_cancer['pop2014_60to64']+ pop_and_cancer['pop2014_65to69'] + pop_and_cancer['pop2014_70to74']+ pop_and_cancer['pop2014_75to79']+ pop_and_cancer['pop2014_80to84']+ pop_and_cancer['pop2014_85over']
#pop_and_cancer['over_50_2014']

# %%
pop_and_cancer['over_50_2017'] = pop_and_cancer['pop2017_50to54'] + pop_and_cancer['pop2017_55to59'] + pop_and_cancer['pop2017_60to64'] + pop_and_cancer['pop2017_65to69'] + pop_and_cancer['pop2017_70to74'] + pop_and_cancer['pop2017_75to79'] + pop_and_cancer['pop2017_80to84'] + pop_and_cancer['pop2017_85over']

# %%
#pop_and_cancer ['percent_pop_over_50_2010'] = pop_and_cancer['over_50_2010'] / pop_and_cancer

pop_and_cancer ['pop2010all']
# Out:
# 0      75112.0
# 1      45086.0
# 2      16511.0
# 3      12882.0
# 4     123213.0
# 5      99096.0
# 6      40735.0
# 7      13801.0
# 8      28448.0
# 9      57340.0
# 10     39122.0
# 11     17193.0
# 12     32216.0
# 13      7851.0
# 14     35641.0
# 15     52770.0
# 16     14588.0
# 17     56197.0
# 18    627973.0
# 19     11718.0
# 20     18695.0
# 21     49693.0
# 22     38318.0
# 23     38429.0
# 24     17920.0
# 25     40961.0
# 26     49734.0
# 27     29420.0
# 28     22721.0
# 29     68838.0
#         ...
# 65     31821.0
# 66     22094.0
# 67      7938.0
# 68      5073.0
# 69     16817.0
# 70     72569.0
# 71     31857.0
# 72     54157.0
# 73     66355.0
# 74    263747.0
# 75     22227.0
# 76     14127.0
# 77     89948.0
# 78    928552.0
# 79     19125.0
# 80     13349.0
# 81    156755.0
# 82    161199.0
# 83     61066.0
# 84      7874.0
# 85     18284.0
# 86     19118.0
# 87      5569.0
# 88     39860.0
# 89    123386.0
# 90     16987.0
# 91     35042.0
# 92     25821.0
# 93    184130.0
# 94    114677.0
# Name: pop2010all, Length: 95, dtype: float64

# %%
pop_and_cancer ['percent_pop_over_50_2010'] = pop_and_cancer['over_50_2010'] / pop_and_cancer['pop2010all']

# %%
pop_and_cancer ['percent_pop_over_50_2010']
# Out:
# 0     0.393679
# 1     0.312026
# 2     0.433590
# 3     0.377659
# 4     0.373800
# 5     0.333818
# 6     0.383650
# 7     0.368596
# 8     0.386460
# 9     0.388751
# 10    0.323271
# 11    0.327226
# 12    0.376024
# 13    0.419819
# 14    0.395528
# 15    0.356737
# 16    0.356183
# 17    0.479225
# 18    0.280275
# 19    0.422768
# 20    0.367531
# 21    0.331133
# 22    0.346600
# 23    0.387494
# 24    0.390179
# 25    0.384292
# 26    0.361181
# 27    0.387458
# 28    0.380969
# 29    0.394157
#         ...
# 65    0.382106
# 66    0.383634
# 67    0.411565
# 68    0.462251
# 69    0.389308
# 70    0.327013
# 71    0.363688
# 72    0.424285
# 73    0.315229
# 74    0.241447
# 75    0.329779
# 76    0.369080
# 77    0.369358
# 78    0.289482
# 79    0.346458
# 80    0.387220
# 81    0.405844
# 82    0.325008
# 83    0.299545
# 84    0.349505
# 85    0.428571
# 86    0.354064
# 87    0.423415
# 88    0.351179
# 89    0.353111
# 90    0.362100
# 91    0.340277
# 92    0.387630
# 93    0.302683
# 94    0.328244
# Name: percent_pop_over_50_2010, Length: 95, dtype: float64

# %%
pop_and_cancer ['percent_pop_over_50_2014'] = pop_and_cancer['over_50_2014'] / pop_and_cancer['pop2014all']

# %%
pop_and_cancer ['percent_pop_over_50_2014']
# Out:
# 0     0.409751
# 1     0.332325
# 2     0.452955
# 3     0.394271
# 4     0.400860
# 5     0.352212
# 6     0.404211
# 7     0.393198
# 8     0.397454
# 9     0.419158
# 10    0.356050
# 11    0.349512
# 12    0.398585
# 13    0.446786
# 14    0.422318
# 15    0.370602
# 16    0.378286
# 17    0.500035
# 18    0.291642
# 19    0.444606
# 20    0.386076
# 21    0.358053
# 22    0.364802
# 23    0.428787
# 24    0.420002
# 25    0.400334
# 26    0.371658
# 27    0.414065
# 28    0.403411
# 29    0.418440
#         ...
# 65    0.400844
# 66    0.401358
# 67    0.419491
# 68    0.483623
# 69    0.414025
# 70    0.338780
# 71    0.377740
# 72    0.451606
# 73    0.342660
# 74    0.263492
# 75    0.351496
# 76    0.400096
# 77    0.393391
# 78    0.309197
# 79    0.375118
# 80    0.411560
# 81    0.423211
# 82    0.347148
# 83    0.331254
# 84    0.372576
# 85    0.448143
# 86    0.388257
# 87    0.453211
# 88    0.369560
# 89    0.367437
# 90    0.387241
# 91    0.360226
# 92    0.400854
# 93    0.323600
# 94    0.354506
# Name: percent_pop_over_50_2014, Length: 95, dtype: float64

# %%
pop_and_cancer ['percent_pop_over_50_2017'] = pop_and_cancer['over_50_2017'] / pop_and_cancer['pop2017all']

# %%
pop_and_cancer.loc[pop_and_cancer.percent_pop_over_50_2017 > 0.50]
# Out:
#         county  pop2010all  pop2014all  pop2017all  median_age_2010  \
# 17  Cumberland     56197.0     57836.0     59078.0             48.4
# 68     Pickett      5073.0      5068.0      5073.0             47.4
#
#     median_age_2014  median_age_2017   FIPS met_healthy_hbjective  \
# 17             50.0             51.4  47035                    No
# 68             48.8             50.4  47137                   Yes
#
#     age_adjusted_death_rate_per_100k            ...             \
# 17                             174.4            ...
# 68                             158.7            ...
#
#     5year_trend_death_rates  lower_95%_CI_2  Upper_95%_CU_2 hospice_count  \
# 17                     -0.8            -1.3            -0.3             1
# 68                     -0.5            -1.8             0.9             0
#
#     over_50_2010  over_50_2014  over_50_2017  percent_pop_over_50_2010  \
# 17       26931.0       28920.0       30402.0                  0.479225
# 68        2345.0        2451.0        2567.0                  0.462251
#
#     percent_pop_over_50_2014  percent_pop_over_50_2017
# 17                  0.500035                  0.514608
# 68                  0.483623                  0.506012
#
# [2 rows x 24 columns]

# %%
pop_and_cancer.loc[pop_and_cancer.percent_pop_over_50_2017 < 0.33]
# Out:
#         county  pop2010all  pop2014all  pop2017all  median_age_2010  \
# 18    Davidson    627973.0    670314.0    691243.0             34.0
# 62  Montgomery    173168.0    188979.0    200182.0             30.0
# 74  Rutherford    263747.0    288608.0    317157.0             32.3
# 78      Shelby    928552.0    938434.0    936961.0             34.6
# 84   Trousdale      7874.0      7993.0     10083.0             39.7
#
#     median_age_2014  median_age_2017   FIPS met_healthy_hbjective  \
# 18             34.4             34.4  47037                    No
# 62             30.3             30.8  47125                    No
# 74             33.3             33.7  47149                    No
# 78             35.1             35.6  47157                    No
# 84             40.7             35.6  47169                    No
#
#     age_adjusted_death_rate_per_100k            ...             \
# 18                             184.7            ...
# 62                             188.4            ...
# 74                             170.3            ...
# 78                             195.0            ...
# 84                             265.5            ...
#
#     5year_trend_death_rates  lower_95%_CI_2  Upper_95%_CU_2 hospice_count  \
# 18                     -1.5            -1.7            -1.2             8
# 62                     -1.0            -1.5            -0.5             1
# 74                     -1.4            -1.7            -1.1             1
# 78                     -1.1            -1.2            -1.0             5
# 84                      0.0            -1.3             1.3             0
#
#     over_50_2010  over_50_2014  over_50_2017  percent_pop_over_50_2010  \
# 18      176005.0      195492.0      202902.0                  0.280275
# 62       38782.0       43670.0       47852.0                  0.223956
# 74       63681.0       76046.0       85835.0                  0.241447
# 78      268799.0      290161.0      299623.0                  0.289482
# 84        2752.0        2978.0        3194.0                  0.349505
#
#     percent_pop_over_50_2014  percent_pop_over_50_2017
# 18                  0.291642                  0.293532
# 62                  0.231084                  0.239042
# 74                  0.263492                  0.270639
# 78                  0.309197                  0.319782
# 84                  0.372576                  0.316771
#
# [5 rows x 24 columns]

# %%
#pop_and_cancer ['percent_pop_over_50_2017']

# %%
#pop_and_cancer['percent_pop_over_50_2010'] =
pop_and_cancer.head()
# Out:
#      county  pop2010all  pop2014all  pop2017all  pop2010_50to54  \
# 0  Anderson     75112.0     75131.0     76257.0          5850.0
# 1   Bedford     45086.0     46259.0     48117.0          3043.0
# 2    Benton     16511.0     16176.0     15986.0          1259.0
# 3   Bledsoe     12882.0     14419.0     14717.0          1005.0
# 4    Blount    123213.0    125827.0    129929.0          9152.0
#
#    pop2014_50to54  pop2017_50to54  pop2010_55to59  pop2014_55to59  \
# 0          5690.0          5296.0          5577.0          5689.0
# 1          3207.0          3239.0          2646.0          2938.0
# 2          1204.0          1179.0          1224.0          1239.0
# 3          1216.0          1185.0           903.0          1100.0
# 4          9658.0          9522.0          8657.0          9094.0
#
#    pop2017_55to59            ...             5year_trend_death_rates  \
# 0          5643.0            ...                                -0.7
# 1          3143.0            ...                                -0.7
# 2          1206.0            ...                                 0.3
# 3          1197.0            ...                                -1.3
# 4          9615.0            ...                                -0.9
#
#    lower_95%_CI_2  Upper_95%_CU_2  hospice_count  over_50_2010  over_50_2014  \
# 0            -1.2            -0.2              0       23190.0       24468.0
# 1            -1.4            -0.1              0       11673.0       12809.0
# 2            -0.4             1.1              0        5821.0        5838.0
# 3            -2.3            -0.3              0        4109.0        4780.0
# 4            -1.3            -0.4              1       37649.0       41118.0
#
#    over_50_2017  percent_pop_over_50_2010  percent_pop_over_50_2014  \
# 0       25017.0                  0.308739                  0.325671
# 1       13576.0                  0.258905                  0.276897
# 2        5872.0                  0.352553                  0.360905
# 3        5001.0                  0.318972                  0.331507
# 4       43443.0                  0.305560                  0.326782
#
#    percent_pop_over_50_2017
# 0                  0.328062
# 1                  0.282146
# 2                  0.367321
# 3                  0.339811
# 4                  0.334360
#
# [5 rows x 48 columns]

# %%
data_50_54 = [col for col in pop_and_cancer.columns if '_50to54' in col]
pop_and_cancer = pop_and_cancer.drop(data_50_54, axis = 1)

# %%
pop_and_cancer.head()
# Out:
#      county  pop2010all  pop2014all  pop2017all  pop2010_55to59  \
# 0  Anderson     75112.0     75131.0     76257.0          5577.0
# 1   Bedford     45086.0     46259.0     48117.0          2646.0
# 2    Benton     16511.0     16176.0     15986.0          1224.0
# 3   Bledsoe     12882.0     14419.0     14717.0           903.0
# 4    Blount    123213.0    125827.0    129929.0          8657.0
#
#    pop2014_55to59  pop2017_55to59  pop2010_60to64  pop2014_60to64  \
# 0          5689.0          5643.0          5068.0          5307.0
# 1          2938.0          3143.0          2515.0          2577.0
# 2          1239.0          1206.0          1363.0          1188.0
# 3          1100.0          1197.0           951.0           935.0
# 4          9094.0          9615.0          8310.0          8538.0
#
#    pop2017_60to64            ...             5year_trend_death_rates  \
# 0          5442.0            ...                                -0.7
# 1          2705.0            ...                                -0.7
# 2          1246.0            ...                                 0.3
# 3           995.0            ...                                -1.3
# 4          9116.0            ...                                -0.9
#
#    lower_95%_CI_2  Upper_95%_CU_2  hospice_count  over_50_2010  over_50_2014  \
# 0            -1.2            -0.2              0       29570.0       30785.0
# 1            -1.4            -0.1              0       14068.0       15373.0
# 2            -0.4             1.1              0        7159.0        7327.0
# 3            -2.3            -0.3              0        4865.0        5685.0
# 4            -1.3            -0.4              1       46057.0       50439.0
#
#    over_50_2017  percent_pop_over_50_2010  percent_pop_over_50_2014  \
# 0       31476.0                  0.393679                  0.409751
# 1       16348.0                  0.312026                  0.332325
# 2        7422.0                  0.433590                  0.452955
# 3        6042.0                  0.377659                  0.394271
# 4       53831.0                  0.373800                  0.400860
#
#    percent_pop_over_50_2017
# 0                  0.412762
# 1                  0.339755
# 2                  0.464281
# 3                  0.410546
# 4                  0.414311
#
# [5 rows x 45 columns]

# %%
data_55_59 = [col for col in pop_and_cancer.columns if '_55to59' in col]
pop_and_cancer = pop_and_cancer.drop(data_55_59, axis = 1)

# %%
data_60_64 = [col for col in pop_and_cancer.columns if '_60to64' in col]
pop_and_cancer = pop_and_cancer.drop(data_60_64, axis = 1)

# %%
data_65_69 = [col for col in pop_and_cancer.columns if '_65to69' in col]
pop_and_cancer = pop_and_cancer.drop(data_65_69, axis = 1)

# %%
pop_and_cancer.head()
# Out:
#      county  pop2010all  pop2014all  pop2017all  pop2010_70to74  \
# 0  Anderson     75112.0     75131.0     76257.0          2856.0
# 1   Bedford     45086.0     46259.0     48117.0          1442.0
# 2    Benton     16511.0     16176.0     15986.0           880.0
# 3   Bledsoe     12882.0     14419.0     14717.0           537.0
# 4    Blount    123213.0    125827.0    129929.0          4870.0
#
#    pop2014_70to74  pop2017_70to74  pop2010_75to79  pop2014_75to79  \
# 0          3270.0          3765.0          2276.0          2327.0
# 1          1765.0          1988.0           992.0          1156.0
# 2           952.0          1075.0           562.0           681.0
# 3           663.0           732.0           344.0           421.0
# 4          5955.0          6808.0          3468.0          4074.0
#
#    pop2017_75to79            ...             5year_trend_death_rates  \
# 0          2501.0            ...                                -0.7
# 1          1321.0            ...                                -0.7
# 2           717.0            ...                                 0.3
# 3           510.0            ...                                -1.3
# 4          4663.0            ...                                -0.9
#
#    lower_95%_CI_2  Upper_95%_CU_2  hospice_count  over_50_2010  over_50_2014  \
# 0            -1.2            -0.2              0       29570.0       30785.0
# 1            -1.4            -0.1              0       14068.0       15373.0
# 2            -0.4             1.1              0        7159.0        7327.0
# 3            -2.3            -0.3              0        4865.0        5685.0
# 4            -1.3            -0.4              1       46057.0       50439.0
#
#    over_50_2017  percent_pop_over_50_2010  percent_pop_over_50_2014  \
# 0       31476.0                  0.393679                  0.409751
# 1       16348.0                  0.312026                  0.332325
# 2        7422.0                  0.433590                  0.452955
# 3        6042.0                  0.377659                  0.394271
# 4       53831.0                  0.373800                  0.400860
#
#    percent_pop_over_50_2017
# 0                  0.412762
# 1                  0.339755
# 2                  0.464281
# 3                  0.410546
# 4                  0.414311
#
# [5 rows x 36 columns]

# %%
data_70_74 = [col for col in pop_and_cancer.columns if '_70to74' in col]
pop_and_cancer = pop_and_cancer.drop(data_70_74, axis = 1)

# %%
data_75_79 = [col for col in pop_and_cancer.columns if '_75to79' in col]
pop_and_cancer = pop_and_cancer.drop(data_75_79, axis = 1)

# %%
pop_and_cancer.tail()
# Out:
#         county  pop2010all  pop2014all  pop2017all  pop2010_80to84  \
# 90       Wayne     16987.0     16788.0     16583.0           356.0
# 91     Weakley     35042.0     33987.0     33337.0           743.0
# 92       White     25821.0     26229.0     26753.0           588.0
# 93  Williamson    184130.0    205213.0    226257.0          2261.0
# 94      Wilson    114677.0    125146.0    136442.0          1566.0
#
#     pop2014_80to84  pop2017_80to84  pop2010_85over  pop2014_85over  \
# 90           368.0           407.0           308.0           360.0
# 91           791.0           749.0           742.0           757.0
# 92           630.0           646.0           532.0           566.0
# 93          2638.0          3057.0          2125.0          2708.0
# 94          1832.0          2178.0          1368.0          1620.0
#
#     pop2017_85over           ...             5year_trend_death_rates  \
# 90           381.0           ...                                 0.1
# 91           808.0           ...                                -0.3
# 92           623.0           ...                                -0.6
# 93          3161.0           ...                                -3.8
# 94          1798.0           ...                                -2.0
#
#     lower_95%_CI_2  Upper_95%_CU_2  hospice_count over_50_2010  over_50_2014  \
# 90            -0.6             0.9              1       6151.0        6501.0
# 91            -0.8             0.3              0      11924.0       12243.0
# 92            -1.3             0.0              0      10009.0       10514.0
# 93            -4.8            -2.9              2      55733.0       66407.0
# 94            -2.8            -1.2              0      37642.0       44365.0
#
#     over_50_2017  percent_pop_over_50_2010  percent_pop_over_50_2014  \
# 90        6654.0                  0.362100                  0.387241
# 91       12410.0                  0.340277                  0.360226
# 92       10962.0                  0.387630                  0.400854
# 93       74686.0                  0.302683                  0.323600
# 94       48803.0                  0.328244                  0.354506
#
#    percent_pop_over_50_2017
# 90                 0.401254
# 91                 0.372259
# 92                 0.409748
# 93                 0.330094
# 94                 0.357683
#
# [5 rows x 30 columns]

# %%
data_80_84 = [col for col in pop_and_cancer.columns if '_80to84' in col]
pop_and_cancer = pop_and_cancer.drop(data_80_84, axis = 1)

# %%
data_85over = [col for col in pop_and_cancer.columns if '_85over' in col]
pop_and_cancer = pop_and_cancer.drop(data_85over, axis = 1)

# %%
plt.scatter(pop_and_cancer['percent_pop_over_50_2017'], pop_and_cancer['5year_trend_death_rates'])
plt.xlabel('percent of population over 50')
plt.ylabel('death rate')
plt.title('Relationship between cancer deaths and percent population over 50')
plt.show()

# %%
pop_and_cancer['normalized_hospice_rate'] = pop_and_cancer['hospice_count'] / pop_and_cancer['pop2017all']

# %%
pop_and_cancer['normalized_hospice_rate'] = pop_and_cancer['normalized_hospice_rate'] * 10000

# %%
pop_and_cancer.head()
# Out:
#      county  pop2010all  pop2014all  pop2017all  median_age_2010  \
# 0  Anderson     75112.0     75131.0     76257.0             42.6
# 1   Bedford     45086.0     46259.0     48117.0             36.5
# 2    Benton     16511.0     16176.0     15986.0             45.6
# 3   Bledsoe     12882.0     14419.0     14717.0             42.5
# 4    Blount    123213.0    125827.0    129929.0             41.5
#
#    median_age_2014  median_age_2017   FIPS met_healthy_hbjective  \
# 0             43.3             43.2  47001                    No
# 1             37.2             37.5  47003                    No
# 2             46.7             47.4  47005                    No
# 3             43.3             43.9  47007                    No
# 4             43.1             43.8  47009                    No
#
#    age_adjusted_death_rate_per_100k           ...             lower_95%_CI_2  \
# 0                             180.6           ...                       -1.2
# 1                             182.7           ...                       -1.4
# 2                             233.9           ...                       -0.4
# 3                             170.0           ...                       -2.3
# 4                             168.2           ...                       -1.3
#
#    Upper_95%_CU_2  hospice_count over_50_2010  over_50_2014  over_50_2017  \
# 0            -0.2              0      29570.0       30785.0       31476.0
# 1            -0.1              0      14068.0       15373.0       16348.0
# 2             1.1              0       7159.0        7327.0        7422.0
# 3            -0.3              0       4865.0        5685.0        6042.0
# 4            -0.4              1      46057.0       50439.0       53831.0
#
#    percent_pop_over_50_2010  percent_pop_over_50_2014  \
# 0                  0.393679                  0.409751
# 1                  0.312026                  0.332325
# 2                  0.433590                  0.452955
# 3                  0.377659                  0.394271
# 4                  0.373800                  0.400860
#
#    percent_pop_over_50_2017  normalized_hospice_rate
# 0                  0.412762                 0.000000
# 1                  0.339755                 0.000000
# 2                  0.464281                 0.000000
# 3                  0.410546                 0.000000
# 4                  0.414311                 0.076965
#
# [5 rows x 25 columns]

# %%
plt.scatter(pop_and_cancer['percent_pop_over_50_2017'], pop_and_cancer['normalized_hospice_rate'])
plt.xlabel('percent of population over 50')
plt.ylabel('hospice rate')
plt.title('Relationship between cancer deaths and normalized hospice rate')
plt.show()

# %%
sns.boxplot(pop_and_cancer['normalized_hospice_rate'], pop_and_cancer['met_healthy_hbjective'])
